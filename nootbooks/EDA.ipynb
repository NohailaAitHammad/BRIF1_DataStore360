# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../data/raw/Sample - Superstore.csv', encoding="latin-1")
print('Shape: ', df.shape)
df.head(20)
# Out:
# Shape:  (10064, 21)
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 5765    5766  US-2014-126340  11/8/2014  11/14/2014  Standard Class
#
#      Customer ID Customer Name   Segment        Country     City  ...  \
# 5765    EB-13870   Emily Burns  Consumer  United States  Redding  ...
#
#      Postal Code Region       Product ID    Category Sub-Category  \
# 5765   96003.0.0   West  TEC-PH-10004447  Technology       Phones
#
#                           Product Name    Sales  Quantity  Discount   Profit
# 5765  Toshiba IPT2010-SD IPÂ Telephone  333.576       3.0       0.2  25.0182
#
# [1 rows x 21 columns]

# %%
#Shipe Mode Valeur manquante d'apres le customer name manquant
df[df['Customer Name'].isna()]['Ship Mode'].isna().value_counts()
# Out:
# Ship Mode
# False    345
# True       6
# Name: count, dtype: int64

# %%
#Sales Valeur manquante d'apres le customer name manquant
df[df['Customer Name'].isna()]['Sales'].isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 #Sales Valeur manquante d'apres le customer name manquant
# ----> 2 df[df['Customer Name'].isna()]['Sales'].isna().sum().value_counts()
#
# AttributeError: 'numpy.int64' object has no attribute 'value_counts'

# %%
#Ship Date Valeur manquante d'apres le customer name manquant
df[df['Customer Name'].isna()]['Ship Date'].isna().value_counts()
# Out:
# Ship Date
# False    347
# True       4
# Name: count, dtype: int64

# %%
#Postal code Valeur manquante d'apres le customer name manquant
df[df['Customer Name'].isna()]['Postal Code'].isna().value_counts()
# Out:
# Postal Code
# False    346
# True       5
# Name: count, dtype: int64

# %%
df.isna().corr()
# Out:
#                Row ID  Order ID  Order Date  Ship Date  Ship Mode  \
# Row ID            NaN       NaN         NaN        NaN        NaN
# Order ID          NaN       NaN         NaN        NaN        NaN
# Order Date        NaN       NaN         NaN        NaN        NaN
# Ship Date         NaN       NaN         NaN   1.000000  -0.005974
# Ship Mode         NaN       NaN         NaN  -0.005974   1.000000
# Customer ID       NaN       NaN         NaN        NaN        NaN
# Customer Name     NaN       NaN         NaN   0.002594  -0.014301
# Segment           NaN       NaN         NaN        NaN        NaN
# Country           NaN       NaN         NaN        NaN        NaN
# City              NaN       NaN         NaN        NaN        NaN
# State             NaN       NaN         NaN        NaN        NaN
# Postal Code       NaN       NaN         NaN   0.007092   0.012616
# Region            NaN       NaN         NaN        NaN        NaN
# ...

# %%
df
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0           1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1           2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2           3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3           4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4           5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...       ...             ...         ...         ...             ...
# 10059    1281  CA-2016-160815    9/5/2016    9/6/2016     First Class
# 10060    7699  CA-2017-151799  12/14/2017  12/18/2017  Standard Class
# 10061    8597  CA-2014-111934    5/5/2014    5/7/2014     First Class
# 10062    4962  CA-2014-156587    3/7/2014    3/8/2014     First Class
# 10063    3998  CA-2015-105627    3/8/2015   3/12/2015  Standard Class
#
#       Customer ID      Customer Name      Segment        Country  \
# ...

# %%
def pseudonymize_row(row, salt_key):
    # Concaténation de la valeur et du sel
    data = f"{row}{salt_key}".encode('utf-8')
    # Calcul du HMAC-SHA256
    hashed = hmac.new(salt_key.encode('utf-8'), data, hashlib.sha256).hexdigest()
    return hashed

# Application au DataFrame
df['pseudonymized_id'] = df['Customer Name'].apply(lambda x: pseudonymize_row(x, 'SECRET_SALT_KEY'))
df['pseudonymized_id']
# Out:
# 0        21b5b7c44749bfa1495eed34c4779134ff31494e1957cd...
# 1        21b5b7c44749bfa1495eed34c4779134ff31494e1957cd...
# 2        7ffcc35fb1e9df2315b2b1a75c146697860a79627e08e5...
# 3        140e9ee473e56c04db7eb0f13a818af4d9a1a63161e3ed...
# 4        140e9ee473e56c04db7eb0f13a818af4d9a1a63161e3ed...
#                                ...
# 10059    fc09c44bf1b987867a27f3c1330bb27f291e4313aadd6a...
# 10060    39de06295c0eb9a3611c833c702b8232cc7847a193ee31...
# 10061    f268a86cc4e781c45398e7a2e7404c7e3d0c27202373c6...
# 10062    65ac08f7b52e77dc6b89d878d39717132bdb77137e2661...
# 10063    178e641a2efdc78169fab507404b6e3d23f927fa663b9b...
# Name: pseudonymized_id, Length: 10064, dtype: object
